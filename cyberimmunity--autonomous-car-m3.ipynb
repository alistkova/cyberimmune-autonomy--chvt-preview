# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 3
#
# ## О документе
#
# Версия 1.03
#
# Модуль 3 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 3. Внедрение блоков функциональной и информационной безопасности
# #### Общая идея
#
# Ключевая идея кибериммунной автономности заключается в том, чтобы уже на этапе проектирования внедрить защиту от кибератак как снаружи, так и изнутри - т.е. через уязвимые бортовые информационные системы.
# Мы исходим из того, что абсолютно защищённых систем не бывает, чем больше и сложнее код, тем проще одним ("плохим") в нём спрятать уязвимости, а другим ("хорошим", но уставшим) эти уязвимости не найти.
#
# Поэтому необходимо сделать так, чтобы наиболее критичный код был отделён от некритичного и протестирован особенно тщательно - таким образом можно снизить вероятность успешной атаки и затруднить задачу атакующим.

# %% [markdown]
# #### Цели и предположения безопасности
#
# ##### Цели безопасности
# Устойчивость кибериммунных систем к атакам выражается в том, что поставленные заказчиком **цели безопасности** (ЦБ) не нарушаются даже в условиях кибератак (снаружи и изнутри).
#
# Для наших автономных машинок заказчиком поставлены следующие ЦБ:
#
# 1. При любых обстоятельствах АНТС осуществляет перемещения в пределах заданных ограничений
#
# 2. При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут
#
# 3. При любых обстоятельствах АНТС оставляет груз только в авторизованном пункте назначения
#
# Ниже используется цифро-буквенное обозначение целей безопасности - например, ЦБ1 - первая цель безопасности из списка выше.
#
# ##### Предположения безопасности
# При этом заказчик согласовал с разработчиками следующие **предположения безопасности** (ПБ) - утверждения о смежных системах, которые снимают с разработчиков часть задач для обеспечения целей безопасности:
#
# 1. При любых обстоятельствах только авторизованный персонал имеет физический доступ к критическим узлам АНТС
#
# 2. При любых обстоятельствах только аутентичные и авторизованные операторы имеют доступ к системе планирования заданий
#
# 3. Аутентичные и авторизованные операторы обладают необходимой квалификацией и являются благонадёжными (т.е. не пытаются намеренно причинить ущерб системе или третьим лицам, используя доступ к АНТС)
#
# Ниже используется цифро-буквенное обозначение предположений безопасности - например, ПБ1 - первое предположение безопасности из списка выше.

# %% [markdown]
# ### Киберпрепятствия
#
# Прежде чем мы начнём внедрять механизмы безопасности, посмотрим, что произойдёт с нашей машинкой, если бортовые системы начнут вести себя не так, как мы ожидаем.
#
# Для этого активируем специальный режим работы системы управления и снова запустим машинку по тому же маршруту, который был в конце модуля 2.
#
# После инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# Но вначале нужно из модуля 2 скопировать сюда ваши текущие наработки, а именно ваши реализации классов коммуникационного шлюза (CommunicationGateway), систему навигации (NavigationSystem), управления (ControlSystem), также будем использовать маршрут, который вы создали.

# %%
# вставьте сюда ваш код

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m3"

# %%
# используем то же маршрутное задание, которое было в модуле 2

# %% [markdown]
# Итак, в отличие от, надеемся, успешного завершения маршрута в модуле 2, сейчас ваша машинка ведёт себя совсем иначе. Например, она внезапно едет в совершенно другую сторону (это особенно хорошо видно при использовании СУПА).
# И это ещё не всё, что может пойти не так..
#
# В этой реализации не очень много кода, теоретически, вы можете его весь изучить и устранить "незадокументированные возможности", однако в реальных системах кода гораздо больше. Например, кодовая база проекта с открытым исходным кодом ArduPilot, реализующего в том числе логику автопилота, составляет примерно миллион строк.
#
# Сколько времени вам понадобится, чтобы изучить и протестировать миллион строк кода? А ведь придётся проводить анализ и каждого обновления.. При этом неприятности могут быть хорошо спрятанными и на первый взгляд безобидными, вряд ли злоумышленники облегчат задачу и назовут свои изменения, например, "hacking_the_system" или "allowing_secret_remote_access". Вредоносный код может выглядеть совершенно безобидно или маскироваться под программный дефект.
#
# Поэтому тщательный анализ потребует большого количества ресурсов (человеческих, вычислительных, временныз), что стоит дорого.
#
# Логичным выходом является выделение критичных для целей безопасности проверок в отдельный блок, который протестировать должно быть гораздо проще.

# %% [markdown]
# #### Задания
#
# В этом модуле задание будет состоять из двух частей разной сложности:
#
# **3.1. добавить новый блок - "Ограничитель"** - этот модуль должен будет обеспечить соблюдение ограничений, указанных в маршрутном задании - это необходимо для обеспечения ЦБ1
#
# **З.2. *(задание повышенной сложности)* добавить монитор безопасности (МБ)** - он должен контролировать все взаимодействия *бортовых систем* (т.е. не включая планировщик и симулятор) и не давать блокам взаимодействовать друг с другом непредусмотренным образом - например, блок №5 может принимать команды только от №3, попытка передать команду в №5 от №2 должна блокироваться нашим монитором безопасности - потенциально это необходимо для обеспечения всех ЦБ

# %% [markdown]
# Для выполнения первой части задачи 3.1. необходимо для начала изменить архитектуру АНТС как показано на рис. 5
#
# ![Архитектура системы с ограничителем](images/ciac-arch-m31.png)
#
# Рис. 5. Архитектура АНТС с ограничителем (для ЦБ1)

# %% [markdown]
# Код базового класса Ограничителя находится в файле src/safety_block.py
#
# По аналогии с заданием в модуле 1, необходимо создать на основе этого класса свой собственный под названием SafetyBlock, в котором реализовать передачу команд в приводы движения, только перед эти необходимо ещё и проконтролировать их безопасность.
#
# Также необходимо реализовать передачу маршрутного задания из CommunicationGateway в SafetyBlock и координат из модуля Navigation в соответствии со стрелками на рис.5 выше.
#
# Если всё сделано правильно, то Ограничителю будет известно следующее
#
# - _mission - текущее маршрутное задание
# - _position - текущие координаты
#
# После проверки нужно установить значение внутренних переменных
# - _speed - текущая (допустимая) скорость
# - _direction - текущее (допустимое) направление
#
# Желательно завершить следование по маршруту. В критической ситуации, если продолжение маршрута невозможно, следует установить значение скорости и направления в 0, после чего передать эти команды в блок приводов (Servos)

# %% [markdown]
# Базовый сценарий для новой архитектуры можно представить следующим образом (см. рис. 6)
#
# ![Базовый сценарий с блоком безопасности](images/basic-scenario-with-safety-block1.png)
#
# Рис. 6. Базовый сценарий с блоком безопасности

# %% [markdown]
# Заготовка кода SafetyBlock
#
# ```python
# class SafetyBlock(BaseSafetyBlock):
#     """ класс ограничений безопасности """
#
#     def _set_new_direction(self, direction: float):
#         """ установка нового направления перемещения """
#         self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
#         self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
#         self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
#         # TODO реализовать контроль безопасности изменения направления
#         self._direction = direction
#         self._send_direction_to_consumers()
#
#     def _set_new_speed(self, speed: float):
#         """ установка новой скорости """
#         # TODO реализовать контроль безопасности изменения скорости
#         self._speed = speed
#         self._send_speed_to_consumers()
#
#
#     def _send_speed_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем скорость получателям")
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_speed",
#                             parameters=self._speed
#                             )
#         servos_q.put(event_speed)
#
#     def _send_direction_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем направление получателям")
#
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_direction",
#                             parameters=self._direction
#                             )
#         servos_q.put(event_speed)
# ```

# %%
# 1. скопируйте сюда код заготовки из предыдущей ячейки и напишите свою реализацию класса SafetyBlock
from multiprocessing import Queue
from src.event_types import Event
from src.safety_block import BaseSafetyBlock
from src.config import LOG_FAILURE, LOG_DEBUG, LOG_ERROR, LOG_INFO
from src.config import SERVOS_QUEUE_NAME
import math


# 1. скопируйте сюда код заготовки из предыдущей ячейки и напишите свою реализацию класса SafetyBlock
class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        
        if not self._mission or not self._position or not self._route or not self._route.next_point():
            self._log_message(LOG_ERROR, "Неизвестный маршрут")
            self._stop_afcs()
            return
        
        if not self._route.next_point():
            self._log_message(LOG_FAILURE, "Нет следующей точки маршрута.")
            self._stop_afcs()
            return
        
        next_direction = self._calculate_direction()
        error_direction = 1

        if (abs(next_direction - direction) > error_direction):
            self._log_message(LOG_ERROR, "Внештатное изменение направления движения.")

        self._direction = next_direction
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут")
            self._stop_afcs()
            return

        allowed_speed = self._route.calculate_speed()
        if allowed_speed < speed:
            self._log_message(LOG_ERROR, f"Внештатное превышение скорости: {speed}. Разрешенная скорость: {allowed_speed}")
            self._speed = allowed_speed
        else:
            self._speed = speed
        
        self._send_speed_to_consumers()


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)
    
    def _stop_afcs(self):
        self._direction = 0
        self._speed = 0
        self._log_message(LOG_FAILURE, "АНТС принудительно остановлено.")

    def _calculate_direction(self):
        current_lattitude = math.radians(self._position.latitude)
        next_lattitude = math.radians(self._route.next_point().latitude)
        delta_longtitude = math.radians(self._route.next_point().longitude - self._position.longitude)

        x = math.sin(delta_longtitude) * math.cos(next_lattitude)
        y = math.cos(current_lattitude) * math.sin(next_lattitude) - \
            math.sin(current_lattitude) * math.cos(next_lattitude) * math.cos(delta_longtitude)

        return (math.degrees(math.atan2(x, y)) + 360) % 360

# %%
# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6
from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.config import CONTROL_SYSTEM_QUEUE_NAME, CONTROL_SYSTEM_QUEUE_NAME, CARGO_BAY_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME
from src.event_types import Event
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.queues_dir import QueuesDirectory


class CommunicationGateway(BaseCommunicationGateway):
    def _send_mission_to_consumers(self):
        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        
        safety_event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        control_q.put(event)
        safety_q.put(safety_event)


class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):

        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        event_speed = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="set_speed",
            parameters=speed
        )

        event_direction = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="set_direction",
            parameters=direction
        )

        safety_q.put(event_speed)
        safety_q.put(event_direction)   

class NavigationSystem(BaseNavigationSystem):
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event = Event(
            source=self.event_source_name,
            destination=control_q_name,
            operation="position_update",
            parameters=self._position
        )

        safety_event = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="position_update",
            parameters=self._position
        )

        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        control_q.put(event)
        safety_q.put(safety_event)

# 3. создайте экземпляры изменённых классов и отправьте машинку по ранее предложенному маршруту
queues_dir = QueuesDirectory() 

control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)
# Out:
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь communication

# %%
from time import sleep


from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser

# # возьмём маршрут из модуля 2
wpl_file = "module2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 30),
    GeoSpecificSpeedLimit(3, 60),
    GeoSpecificSpeedLimit(5, 20),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# создадим все остальные компоненты

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)
# Out:
# [Point(59.874951, 29.825225, 0.0), Point(59.876145, 29.828535, 0.0), Point(59.876897, 29.829177, 0.0), Point(59.878121, 29.824136, 0.0), Point(59.881917, 29.827542, 0.0), Point(59.884427, 29.827059, 0.0), Point(59.886274, 29.828739, 0.0), Point(59.886479, 29.832717, 0.0)]
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель

# %%
# соберём все компоненты для запуска

# в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(205)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.8236s N, 29 49m 30.81s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.8236s N, 29 49m 30.81s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.8236s N, 29 49m 30.81s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.9022s N, 29 49m 31.0275s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.9808s N, 29 49m 31.2449s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0593s N, 29 49m 31.4624s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1379s N, 29 49m 31.6798s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2008s N, 29 49m 31.8538s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2794s N, 29 49m 32.0713s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3579s N, 29 49m 32.2888s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4365s N, 29 49m 32.5062s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5151s N, 29 49m 32.7237s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5937s N, 29 49m 32.9412s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.6722s N, 29 49m 33.1587s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.7508s N, 29 49m 33.3762s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.8293s N, 29 49m 33.5936s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.9079s N, 29 49m 33.8111s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.9865s N, 29 49m 34.0286s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.065s N, 29 49m 34.2461s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.1436s N, 29 49m 34.4636s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.2221s N, 29 49m 34.6811s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.3007s N, 29 49m 34.8986s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.3792s N, 29 49m 35.1162s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.4578s N, 29 49m 35.3337s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.5363s N, 29 49m 35.5512s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.6148s N, 29 49m 35.7687s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.6934s N, 29 49m 35.9863s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.7719s N, 29 49m 36.2038s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.8504s N, 29 49m 36.4213s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.929s N, 29 49m 36.6389s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.0075s N, 29 49m 36.8564s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.086s N, 29 49m 37.074s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.1645s N, 29 49m 37.2915s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.243s N, 29 49m 37.5091s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.3216s N, 29 49m 37.7267s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.4001s N, 29 49m 37.9442s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.4786s N, 29 49m 38.1618s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.5571s N, 29 49m 38.3794s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.6355s N, 29 49m 38.597s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.714s N, 29 49m 38.8146s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.7925s N, 29 49m 39.0322s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.871s N, 29 49m 39.2498s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.9495s N, 29 49m 39.4674s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.0279s N, 29 49m 39.6851s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.1064s N, 29 49m 39.9027s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.1848s N, 29 49m 40.1204s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.2633s N, 29 49m 40.338s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.3417s N, 29 49m 40.5557s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.4201s N, 29 49m 40.7734s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.4986s N, 29 49m 40.9911s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.577s N, 29 49m 41.2088s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.6554s N, 29 49m 41.4265s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.7338s N, 29 49m 41.6443s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.8121s N, 29 49m 41.8621s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.8905s N, 29 49m 42.0799s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.9688s N, 29 49m 42.2977s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.0471s N, 29 49m 42.5156s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.1253s N, 29 49m 42.7336s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.2035s N, 29 49m 42.9516s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.326s N, 29 49m 43.0625s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.4498s N, 29 49m 43.1678s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.5749s N, 29 49m 43.267s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.675s N, 29 49m 43.3459s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.8003s N, 29 49m 43.4442s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9255s N, 29 49m 43.5424s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.0508s N, 29 49m 43.6405s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.176s N, 29 49m 43.7387s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.3013s N, 29 49m 43.8369s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4266s N, 29 49m 43.9351s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5518s N, 29 49m 44.0333s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6771s N, 29 49m 44.1316s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.8023s N, 29 49m 44.2298s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.9276s N, 29 49m 44.3281s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.0528s N, 29 49m 44.4264s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.1781s N, 29 49m 44.5247s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3033s N, 29 49m 44.623s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.4285s N, 29 49m 44.7214s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.5538s N, 29 49m 44.8198s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.679s N, 29 49m 44.9182s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.8042s N, 29 49m 45.0167s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9293s N, 29 49m 45.1154s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9899s N, 29 49m 44.8762s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0489s N, 29 49m 44.6354s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1062s N, 29 49m 44.3931s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1635s N, 29 49m 44.1508s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2208s N, 29 49m 43.9084s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2781s N, 29 49m 43.666s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3354s N, 29 49m 43.4236s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3927s N, 29 49m 43.1813s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4499s N, 29 49m 42.9389s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5072s N, 29 49m 42.6965s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5645s N, 29 49m 42.4541s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6218s N, 29 49m 42.2117s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.679s N, 29 49m 41.9694s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7363s N, 29 49m 41.727s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7936s N, 29 49m 41.4846s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8509s N, 29 49m 41.2422s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9081s N, 29 49m 40.9998s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9654s N, 29 49m 40.7574s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0227s N, 29 49m 40.515s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0799s N, 29 49m 40.2726s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1372s N, 29 49m 40.0302s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1944s N, 29 49m 39.7878s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2517s N, 29 49m 39.5454s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.309s N, 29 49m 39.303s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3662s N, 29 49m 39.0606s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4235s N, 29 49m 38.8182s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4807s N, 29 49m 38.5758s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.538s N, 29 49m 38.3334s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5952s N, 29 49m 38.091s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6525s N, 29 49m 37.8486s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7097s N, 29 49m 37.6062s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.767s N, 29 49m 37.3638s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8242s N, 29 49m 37.1213s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8814s N, 29 49m 36.8789s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9387s N, 29 49m 36.6365s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9845s N, 29 49m 36.4426s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0417s N, 29 49m 36.2001s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0989s N, 29 49m 35.9577s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1561s N, 29 49m 35.7153s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2134s N, 29 49m 35.4729s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2706s N, 29 49m 35.2304s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3278s N, 29 49m 34.988s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.385s N, 29 49m 34.7456s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4423s N, 29 49m 34.5031s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4995s N, 29 49m 34.2607s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5567s N, 29 49m 34.0182s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6139s N, 29 49m 33.7758s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6711s N, 29 49m 33.5333s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7283s N, 29 49m 33.2909s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7855s N, 29 49m 33.0484s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8427s N, 29 49m 32.8059s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8999s N, 29 49m 32.5635s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9571s N, 29 49m 32.321s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0143s N, 29 49m 32.0785s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0714s N, 29 49m 31.8361s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1286s N, 29 49m 31.5936s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1858s N, 29 49m 31.3511s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.243s N, 29 49m 31.1086s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3001s N, 29 49m 30.8661s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3573s N, 29 49m 30.6236s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4144s N, 29 49m 30.3811s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4716s N, 29 49m 30.1386s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5287s N, 29 49m 29.8961s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5859s N, 29 49m 29.6536s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.643s N, 29 49m 29.4111s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.7001s N, 29 49m 29.1685s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.7572s N, 29 49m 28.926s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.8143s N, 29 49m 28.6834s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.8714s N, 29 49m 28.4409s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.9285s N, 29 49m 28.1983s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.9856s N, 29 49m 27.9557s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.0426s N, 29 49m 27.7131s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.0996s N, 29 49m 27.4705s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.1566s N, 29 49m 27.2279s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.2136s N, 29 49m 26.9852s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.2705s N, 29 49m 26.7425s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.3273s N, 29 49m 26.4996s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.5732s N, 29 49m 26.7178s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.8182s N, 29 49m 26.9404s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.0621s N, 29 49m 27.1673s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.3059s N, 29 49m 27.3944s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.5498s N, 29 49m 27.6215s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.7937s N, 29 49m 27.8487s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.0375s N, 29 49m 28.0759s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.2814s N, 29 49m 28.3031s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.5252s N, 29 49m 28.5303s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.7691s N, 29 49m 28.7575s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.0129s N, 29 49m 28.9848s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.2568s N, 29 49m 29.212s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.5006s N, 29 49m 29.4393s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.7445s N, 29 49m 29.6665s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.9883s N, 29 49m 29.8938s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.2321s N, 29 49m 30.1211s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.4272s N, 29 49m 30.3029s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.671s N, 29 49m 30.5302s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.9149s N, 29 49m 30.7575s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.1587s N, 29 49m 30.9848s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.4025s N, 29 49m 31.2121s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.6464s N, 29 49m 31.4394s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.8902s N, 29 49m 31.6668s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.134s N, 29 49m 31.8941s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.3778s N, 29 49m 32.1215s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.6216s N, 29 49m 32.3489s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.8655s N, 29 49m 32.5763s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.1093s N, 29 49m 32.8037s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.3531s N, 29 49m 33.0311s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.5969s N, 29 49m 33.2585s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.8407s N, 29 49m 33.4859s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.0845s N, 29 49m 33.7134s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.3283s N, 29 49m 33.9408s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.5721s N, 29 49m 34.1683s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.8159s N, 29 49m 34.3958s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.0596s N, 29 49m 34.6233s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.3034s N, 29 49m 34.8508s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.5472s N, 29 49m 35.0784s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.791s N, 29 49m 35.306s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.0347s N, 29 49m 35.5336s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.2785s N, 29 49m 35.7612s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.5222s N, 29 49m 35.9888s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.766s N, 29 49m 36.2165s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.0097s N, 29 49m 36.4442s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.2535s N, 29 49m 36.6719s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.4972s N, 29 49m 36.8997s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.7409s N, 29 49m 37.1275s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.9846s N, 29 49m 37.3553s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.2283s N, 29 49m 37.5831s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.472s N, 29 49m 37.811s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7157s N, 29 49m 38.039s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9594s N, 29 49m 38.267s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.203s N, 29 49m 38.4951s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4467s N, 29 49m 38.7233s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6903s N, 29 49m 38.9516s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.9338s N, 29 49m 39.1801s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.1773s N, 29 49m 39.4089s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.4205s N, 29 49m 39.6387s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.6885s N, 29 49m 39.5862s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 55.956s N, 29 49m 39.5253s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.223s N, 29 49m 39.4556s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.49s N, 29 49m 39.3854s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 56.7569s N, 29 49m 39.3149s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.0238s N, 29 49m 39.2443s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.2908s N, 29 49m 39.1737s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.5577s N, 29 49m 39.1031s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 57.8246s N, 29 49m 39.0325s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.0915s N, 29 49m 38.9619s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.3585s N, 29 49m 38.8913s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.6254s N, 29 49m 38.8206s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 58.8923s N, 29 49m 38.75s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.1059s N, 29 49m 38.6935s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.3728s N, 29 49m 38.6229s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.6397s N, 29 49m 38.5522s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 59.9066s N, 29 49m 38.4816s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.173546s N, 29 49m 38.4109s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.440468s N, 29 49m 38.3402s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.707389s N, 29 49m 38.2695s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 0.97431s N, 29 49m 38.1989s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.24123s N, 29 49m 38.1282s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.50815s N, 29 49m 38.0574s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 1.77507s N, 29 49m 37.9867s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.04198s N, 29 49m 37.916s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.3089s N, 29 49m 37.8452s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.57581s N, 29 49m 37.7744s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 2.84273s N, 29 49m 37.7036s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.10964s N, 29 49m 37.6328s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.37655s N, 29 49m 37.5619s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.64346s N, 29 49m 37.491s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 53m 3.91036s N, 29 49m 37.4201s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 4.17725s N, 29 49m 37.349s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 4.44413s N, 29 49m 37.2777s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 4.52586s N, 29 49m 37.3515s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 4.60683s N, 29 49m 37.4286s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 4.68695s N, 29 49m 37.5091s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 4.76705s N, 29 49m 37.5897s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 4.84714s N, 29 49m 37.6703s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 4.92722s N, 29 49m 37.751s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 5.00731s N, 29 49m 37.8316s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 5.08739s N, 29 49m 37.9123s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 5.16747s N, 29 49m 37.9929s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 5.24756s N, 29 49m 38.0736s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 5.32764s N, 29 49m 38.1542s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 5.40772s N, 29 49m 38.2349s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 5.4878s N, 29 49m 38.3156s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 5.56789s N, 29 49m 38.3962s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 5.64797s N, 29 49m 38.4769s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 5.72805s N, 29 49m 38.5575s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 5.80813s N, 29 49m 38.6382s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 5.88821s N, 29 49m 38.7189s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 5.96829s N, 29 49m 38.7996s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 6.04836s N, 29 49m 38.8802s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 6.12844s N, 29 49m 38.9609s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 6.20852s N, 29 49m 39.0416s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 6.2886s N, 29 49m 39.1223s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 6.36867s N, 29 49m 39.203s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 6.44875s N, 29 49m 39.2836s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 6.52883s N, 29 49m 39.3643s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 6.6089s N, 29 49m 39.445s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 6.68897s N, 29 49m 39.5257s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 6.76905s N, 29 49m 39.6064s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 6.84912s N, 29 49m 39.6871s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 6.92919s N, 29 49m 39.7678s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 7.00927s N, 29 49m 39.8485s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 7.08934s N, 29 49m 39.9292s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 7.16941s N, 29 49m 40.0099s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 7.24948s N, 29 49m 40.0906s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 7.32955s N, 29 49m 40.1713s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 7.3936s N, 29 49m 40.2359s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 7.47367s N, 29 49m 40.3166s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 7.55374s N, 29 49m 40.3973s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 7.6338s N, 29 49m 40.4781s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 7.71387s N, 29 49m 40.5588s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 7.79393s N, 29 49m 40.6395s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 7.874s N, 29 49m 40.7202s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 7.95406s N, 29 49m 40.801s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 8.03413s N, 29 49m 40.8817s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 8.11419s N, 29 49m 40.9624s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 8.19425s N, 29 49m 41.0432s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 8.27431s N, 29 49m 41.1239s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 8.35437s N, 29 49m 41.2047s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 8.43442s N, 29 49m 41.2855s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 8.51448s N, 29 49m 41.3662s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 8.59454s N, 29 49m 41.447s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 8.67459s N, 29 49m 41.5278s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 8.75464s N, 29 49m 41.6085s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 8.8347s N, 29 49m 41.6893s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 8.91475s N, 29 49m 41.7701s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 8.9948s N, 29 49m 41.8509s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 9.07485s N, 29 49m 41.9317s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 9.15489s N, 29 49m 42.0125s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 9.23494s N, 29 49m 42.0933s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 9.31498s N, 29 49m 42.1741s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 9.39502s N, 29 49m 42.2549s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 9.47506s N, 29 49m 42.3358s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 9.5551s N, 29 49m 42.4166s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 9.63514s N, 29 49m 42.4974s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 9.71517s N, 29 49m 42.5783s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 9.7952s N, 29 49m 42.6592s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 9.87523s N, 29 49m 42.74s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 9.95525s N, 29 49m 42.8209s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.0353s N, 29 49m 42.9018s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.1153s N, 29 49m 42.9827s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.1953s N, 29 49m 43.0637s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.2753s N, 29 49m 43.1446s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.3553s N, 29 49m 43.2256s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.4353s N, 29 49m 43.3066s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.5153s N, 29 49m 43.3877s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.5953s N, 29 49m 43.4688s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.6752s N, 29 49m 43.55s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.6852s N, 29 49m 43.7275s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.6943s N, 29 49m 43.9052s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.7024s N, 29 49m 44.083s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.7105s N, 29 49m 44.2609s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.7186s N, 29 49m 44.4388s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.7267s N, 29 49m 44.6167s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.7348s N, 29 49m 44.7945s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.7429s N, 29 49m 44.9724s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.751s N, 29 49m 45.1503s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.7591s N, 29 49m 45.3281s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.7671s N, 29 49m 45.506s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.7752s N, 29 49m 45.6839s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.7833s N, 29 49m 45.8618s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.7898s N, 29 49m 46.0041s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.7979s N, 29 49m 46.1819s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.806s N, 29 49m 46.3598s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.8141s N, 29 49m 46.5377s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.8222s N, 29 49m 46.7155s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.8303s N, 29 49m 46.8934s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.8383s N, 29 49m 47.0713s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.8464s N, 29 49m 47.2492s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.8545s N, 29 49m 47.427s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.8626s N, 29 49m 47.6049s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.8707s N, 29 49m 47.7828s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.8788s N, 29 49m 47.9607s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.8869s N, 29 49m 48.1385s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.895s N, 29 49m 48.3164s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.903s N, 29 49m 48.4943s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.9111s N, 29 49m 48.6721s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.9192s N, 29 49m 48.85s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.9273s N, 29 49m 49.0279s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.9354s N, 29 49m 49.2058s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.9435s N, 29 49m 49.3836s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.9516s N, 29 49m 49.5615s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.9596s N, 29 49m 49.7394s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.9677s N, 29 49m 49.9173s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.9758s N, 29 49m 50.0951s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.9839s N, 29 49m 50.273s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 10.992s N, 29 49m 50.4509s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.0001s N, 29 49m 50.6288s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.0081s N, 29 49m 50.8066s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.0162s N, 29 49m 50.9845s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.0243s N, 29 49m 51.1624s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.0324s N, 29 49m 51.3402s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.0405s N, 29 49m 51.5181s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.0485s N, 29 49m 51.696s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.0566s N, 29 49m 51.8739s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.0647s N, 29 49m 52.0517s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.0728s N, 29 49m 52.2296s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.0809s N, 29 49m 52.4075s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.0889s N, 29 49m 52.5854s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.097s N, 29 49m 52.7632s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.1051s N, 29 49m 52.9411s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.1132s N, 29 49m 53.119s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.1212s N, 29 49m 53.2969s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.1293s N, 29 49m 53.4747s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.1374s N, 29 49m 53.6526s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.1455s N, 29 49m 53.8305s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.1535s N, 29 49m 54.0084s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.1616s N, 29 49m 54.1863s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.1697s N, 29 49m 54.3641s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.1777s N, 29 49m 54.542s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.1858s N, 29 49m 54.7199s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.1939s N, 29 49m 54.8978s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.202s N, 29 49m 55.0756s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.21s N, 29 49m 55.2535s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.2181s N, 29 49m 55.4314s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.2261s N, 29 49m 55.6093s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.2342s N, 29 49m 55.7871s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.2423s N, 29 49m 55.965s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.2503s N, 29 49m 56.1429s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.2584s N, 29 49m 56.3208s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.2648s N, 29 49m 56.4631s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.2729s N, 29 49m 56.641s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.2809s N, 29 49m 56.8188s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.289s N, 29 49m 56.9967s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.2971s N, 29 49m 57.1746s E
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.3051s N, 29 49m 57.3525s E
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] текущие координаты: 59 53m 11.3131s N, 29 49m 57.5304s E
# [ОШИБКА][SAFETY] Неизвестный маршрут
# [ОТКАЗ][SAFETY] АНТС принудительно остановлено.
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# #### Обеспечение ЦБ3: контроль доставки груза
#
# С помощью логики ограничителя выше мы реализовали обеспечение ЦБ1 (соблюдение заданных ограничений), однако есть ещё ЦБ3 (отгрузка только в заданной точке), не говоря о ЦБ2 (следование только по аутентичному маршруту).
#
# Для обеспечения ЦБ3 необходимо сделать следующее
# 1. изменить последовательность передачи команд, чтобы в блок управления грузовым отсеком (CargoBay) команды приходили только после проверки в Ограничителе
# 2. доработайте реализацию Ограничителя, чтобы команда на выгрузку передавалась в CargoBay только в конечной точке маршрута
# 3. продумайте логику работы блока безопасности, если система управления полностью перестанет работать (т.е. перестанет отправлять новые команды).
#
# Изменённая архитектура приведена на рис. 7.
#
# ![Ограничитель для обеспечения ЦБ1 и ЦБ3](images/ciac-arch-m312.png)
#
# Рис. 7. Ограничитель для обеспечения ЦБ1 и ЦБ3

# %%
# напишите свой код в этой ячейке, запустите машинку по маршруту, убедитесь, 
# что в конечной (и только в конечной!) точке CargoBay получает команду и успешно выполняет выгрузку
from multiprocessing import Queue
from src.event_types import Event
from src.safety_block import BaseSafetyBlock
from src.config import LOG_FAILURE, LOG_DEBUG, LOG_ERROR, LOG_INFO
from src.config import SERVOS_QUEUE_NAME
import math

# 1. скопируйте сюда код заготовки из предыдущей ячейки и напишите свою реализацию класса SafetyBlock
class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        
        if not self._mission or not self._position or not self._route or not self._route.next_point():
            self._log_message(LOG_ERROR, "Неизвестный маршрут")
            self._stop_afcs()
            return
        
        if not self._route.next_point():
            self._log_message(LOG_FAILURE, "Нет следующей точки маршрута.")
            self._stop_afcs()
            return
        
        next_direction = self._calculate_direction()
        error_direction = 1

        if (abs(next_direction - direction) > error_direction):
            self._log_message(LOG_ERROR, "Внештатное изменение направления движения.")

        self._direction = next_direction
        self._send_direction_to_consumers()

def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут")
            self._stop_afcs()
            return

        allowed_speed = self._route.calculate_speed()
        if allowed_speed < speed:
            self._log_message(LOG_ERROR, f"Внештатное превышение скорости: {speed}. Разрешенная скорость: {allowed_speed}")
            self._speed = allowed_speed
        else:
            self._speed = speed
        
        self._send_speed_to_consumers()

def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

                # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)

def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека.")
        self._send_lock_cargo_to_consumers()
    
def _release_cargo(self, _):
        if not self._route.route_finished:
            self._log_message(LOG_FAILURE, "АНТС не в конечной точке маршрута. Невозможно разблокировать грузовой отсек.")
            return
        self._send_release_cargo_to_consumers()

def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        cargo_q_name = CARGO_BAY_QUEUE_NAME
        cargo_q = self._queues_dir.get_queue(cargo_q_name)
        # инициализация сообщения с командой на блокировку грузового отсека
        event = Event(
            source=self.event_source_name,
            destination=cargo_q_name,
            operation="lock_cargo",
            parameters=None
        )
        cargo_q.put(event)

def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_INFO, "Разблокировка грузового отсека")
        cargo_q_name = CARGO_BAY_QUEUE_NAME
        cargo_q = self._queues_dir.get_queue(cargo_q_name)
        # инициализация сообщения с командой на разблокировку грузового отсека
        event = Event(
            source=self.event_source_name,
            destination=cargo_q_name,
            operation="release_cargo",
            parameters=None
        )
        cargo_q.put(event)
    
def _stop_afcs(self):
        self._direction = 0
        self._speed = 0
        self._log_message(LOG_FAILURE, "АНТС принудительно остановлено.")
    
def _calculate_direction(self):
        current_lattitude = math.radians(self._position.latitude)
        next_lattitude = math.radians(self._route.next_point().latitude)
        delta_longtitude = math.radians(self._route.next_point().longitude - self._position.longitude)

        x = math.sin(delta_longtitude) * math.cos(next_lattitude)
        y = math.cos(current_lattitude) * math.sin(next_lattitude) - \
            math.sin(current_lattitude) * math.cos(next_lattitude) * math.cos(delta_longtitude)

        return (math.degrees(math.atan2(x, y)) + 360) % 360

# %% [markdown]
# #### *Опциональное задание повышенной сложности* Обеспечение ЦБ2
#
# **Перед началом работы над этой задачей рекомендуем сохранить все текущие изменения в git репозитории (git commit, git push).**
#
# Напомним цель безопасности №2 (ЦБ2): "При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут"
#
# Обеспечение ЦБ2 потребует
# - внедрения механизма **контроля аутентичности маршрутного задания** (mission), а значит
# - помимо изменения **блока безопасности** (SafetyBlock), модификации
#   - системы **планирования задания** (MissionPlanner)
#   - **коммуникационного шлюза** (CommunicationGateway)
#   - и, возможно, **системы управления** (ControlSystem).
#
# Для решения этой задачи допустимо менять код соответствующих модулей в папке src.
#
# Возможным решением является внедрение механизма цифровой подписи, верификацией которой будет заниматься блок безопасности. В этой ситуации если коммуникационный шлюз (блок "1. Связь" на рис. 5 в модуле 1) оказался скомпрометированным и изменил маршрутное задание, оно не должно пройти проверку подлинности в блоке безопасности.
#
# **Рекомендуем эту задачу делать в последнюю очередь**, *после успешного выполнения модуля 4*, поскольку успешное выполнение модуля 4 принесёт больше баллов, чем внедрение цифровой подписи и обеспечение ЦБ2.
# К сведению, реализованные в этой версии киберпрепятствия не предполагают компрометацию маршрутного задания.
#
# Конечно, если будут решены все основные задачи и к тому же обеспечен контроль аутентичности маршрутного задания, такая работа с высокой вероятностью окажется лучшей.

# %%
# если вы собираетесь выполнить это задание, напишите в этой ячейке код выполнения изменённых блоков. 
# cам код допускается редактировать в папке src
# в случае успешной реализации машинка должна успешно пройти по маршруту, а в случае искажения маршрутного задания в блоке коммуникационного шлюза должна остаться на месте, 
# при этом именно блок безопасности должен заблокировать движение

# %% [markdown]
# ### Задание 3.2. Монитор безопасности

# %% [markdown]
# В текущей реализации каждый блок сам решает куда и какие данные ему отправлять. Это приемлемо, когда каждый блок рассматривается как благонадёжный. Однако нельзя исключать ситуацию успешной компрометации какого-либо из блоков (одного или нескольких), в результате которой злоумышленник может получить полный контроль над частью системы.
#
# В такой ситуации необходимо выстроить внутреннюю "поверхность защиты", частью этой системы уже является блок "Ограничитель", однако необходимо сделать так, чтобы соответствующие запросы проходили только через него, а не в обход.
#
# Для решения этой задачи необходимо добавить новый блок "Монитор безопасности". Его задача - обеспечить контроль направления информационных потоков, допустить передачу данных только между теми блоками и в тех направлениях, которые задуманы архитектором системы. Тогда, например, попытка передать команду из системы управления напрямую в сервоприводы в обход ограничителя будет заблокирована.
#
# Возможно, возникнет вопрос, а что помешает злоумышленнику отправить команду в обход этого монитора безопасности. В рамках этой учебной инфраструктуры особо ничего, однако при разработке реальной системы можно использовать специализированные микроядерные операционные системы, такие как, например, KasperskyOS, которые обеспечат обязательное вовлечение монитора безопасности в контроль взаимодействия между блоками.
#
# Архитектура системы для решения задачи 3.2 должна выглядеть как на рис.8:
#
# ![Архитектура системы с монитором безопасности](images/ciac-arch-m32.png)
#
# Рис. 8. Архитектура бортовых систем с монитором безопасности

# %% [markdown]
# Базовый класс модуля безопасности находится в файле src/security_monitor.py, его менять не нужно.
#
# В следующей ячейке находится реализация класса SecurityMonitor

# %%
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission')
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %% [markdown]
# Обратите внимание на этот код:
# ```python
#     def _init_set_security_policies(self):
#         """ инициализация политик безопасности """
#         default_policies = [
#             SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
#         ]
#         self.set_security_policies(policies=default_policies)
# ```
#
# В нём инициализируется политика безопасности, разрешающая запрос set_mission от коммуникационного шлюза в систему управления.
#
# Код политики безопасности в строка 6-9:
# ```python
# SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
# ```
#
# Шаблон политики безопасности описан в файле src/security_policy_type.py:
# ```python
# @dataclass
# class SecurityPolicy:
#     """ политика безопасности """
#     source: str         # отправитель запроса
#     destination: str    # получатель
#     operation: str      # запрашиваемая операция
#
# ```
#
# По аналогии в методе _init_set_security_policies допишите другие политики безопасности, чтобы разрешить взаимодействия согласно диаграмме на рис.7. выше.

# %% [markdown]
# Теперь необходимо изменить взаимодействие между блоками так, чтобы оно всегда проходило через монитор безопасности. Для этого потребуется изменить соответствующие реализации внутренних блоков.

# %% [markdown]
# Ниже пример для блока навигации. Обратите внимание на выделенные строки и комментарии.
#
# ```python
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         # событие для системы управления,
#         # поэтому в destination указываем CONTROL_SYSTEM_QUEUE_NAME
#         event = Event(source=self.event_source_name,
# >>>                      destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         # но событие отправляем сначала на проверку в монитор безопасности,
#         # поэтому используем очередь с именем SECURITY_MONITOR_QUEUE_NAME
# >>>        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#         # а в систему управления наше событие монитор безопасности отправит сам, если найдёт разрешающую эту операцию политику безопасности
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)
# ```

# %% [markdown]
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         event = Event(source=self.event_source_name,
#                       destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)

# %% [markdown]
# В файле tests/module/test_security_monitor.py можно увидеть тест логики работы монитора безопасности. Запустить его можно следующей командой:

# %%
# !pytest -svk security_monitor
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.1, pytest-8.3.4, pluggy-1.5.0 -- /usr/local/py-utils/venvs/pytest/bin/python
# cachedir: .pytest_cache
# rootdir: /workspaces/cyberimmune-autonomy--chvt-preview
# configfile: pytest.ini
# testpaths: tests
# plugins: anyio-4.7.0
# collected 1 item
#
# tests/module/test_security_monitor.py::test_security_policies [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='control', operation='set_mission', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='cargo', operation='release_cargo', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# PASSED
#
# ============================== 1 passed in 0.02s ===============================

# %% [markdown]
# В одном кодовом блоке ниже (или нескольких - как будет удобнее)  сделайте следующее
#
# 1. Измените реализацию монитора безопасности в части правил проверки передаваемых сообщений в мониторе безопасности
# 2. Измените параметры отправки сообщений между элементами бортовых систем (блоками 1-7), чтобы они всегда отправлялись в очередь монитора безопасности (отправитель и получатель при этом не меняются)
# 3. После всех изменений убедитесь в том, что машинка по-прежнему успешно выполняет маршрутное задание и доставляет груз
# 4. Дополнительные баллы принесут автоматические тесты правил безопасности в файле tests/module/test_security_monitor.py - можно проверить, что все новые политики работают как ожидаются, а недопустимые взаимодействия (т.е. таких стрелок нет на рис. 8) блокируются

# %%
# добавьте изменения сюда

# %% [markdown]
# На этом модуль 3 завершён!
#
# Если у вас всё получилось, то вы создали защищённую автономную машинку - ещё уже не так-то просто использовать для нанесения критического ущерба людям и имуществу, потому что самые критические режимы проверяются вашим Ограничителем, а если вы ещё и внедрили Монитор Безопасности, то теперь злоумышленнику гораздо сложнее атаковать внутренние блоки, даже если он смог проникнуть в какую-то бортовую систему или внедрить вредоносный код.
#
# Осталось проверить эффективность получившейся защиты на полной трассе - в этом и заключается модуль 4 задания, для перехода к которому нужно открыть блокнот с именем cyberimmunity--autonomous-car-m4. Успеха!
